# %% [markdown]
# ## SPRINT 1
# ### Data Merging, Data Preprocessing, Data Cleaning, and Saving Cleaned DataOF THI PROJECT

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
players_file=pd.read_excel(r"C:\Users\91994\Desktop\Sprint data\Capstone project data\players.xlsx")
players_file
# Out:
#      player_id                 name  last_season  current_club_id  \
# 0       124732  John Anthony Brooks         2023              533
# 1       223047      Emerson Hyndman         2018              903
# 2       307781         Lynden Gooch         2016              289
# 3       370846         Timothy Weah         2023              506
# 4       484756   Djordje Mihailovic         2023             1090
# ..         ...                  ...          ...              ...
# 147     273570        Desevio Payne         2020             1283
# 148     111783     Alejandro Bedoya         2015              995
# 149     160670             Joe Gyau         2014               16
# 150       3476         Brad Friedel         2014              148
# 151     504215       Giovanni Reyna         2023               16
#
#              player_code country_of_birth date_of_birth        sub_position  \
# 0    john-anthony-brooks          Germany    1993-01-28         Centre-Back
# ...

# %%
games_file=pd.read_excel(r"C:\Users\91994\Desktop\Sprint data\Capstone project data\games.xlsx")
games_file
# Out:
#       game_id competition_id  season         round       date  \
# 0     2222734            RU1    2012  19. Matchday 2012-12-07
# 1     2224572            DK1    2012   3. Matchday 2012-07-28
# 2     2224628            DK1    2012  22. Matchday 2013-03-08
# 3     2224655            DK1    2012  22. Matchday 2013-03-10
# 4     2224729            DK1    2012   1. Matchday 2012-07-15
# ...       ...            ...     ...           ...        ...
# 3263  3296153            NLP    2019   Round of 16 2020-01-22
# 3264  2875216            DK1    2017  19. Matchday 2017-12-10
# 3265  3099247            BE1    2018  11. Matchday 2018-10-20
# 3266  2872273            GB1    2017  16. Matchday 2017-12-09
# 3267  2517322            FAC    2014   Third Round 2015-01-04
#
#       home_club_goals  away_club_goals  home_club_position  \
# 0                   2                3                11.0
# 1                   1                2                12.0
# ...

# %%
game_lineup_file=pd.read_excel(r"C:\Users\91994\Desktop\Sprint data\Capstone project data\game_lineups.xlsx")
game_lineup_file
# Out:
#                       game_lineups_id  game_id             type  number  \
# 0    f2570d1504fc02f4b6c7608e8dcf89a3  4087925      substitutes      34
# 1    f5f0da93ea8e1d8bdd799658e7c8f7cb  4087928  starting_lineup      13
# 2    31a4d12ec23d604779d909d26c1b5410  4087929      substitutes      26
# 3    776dcbef98651450db76723cb7e3b4df  4087935      substitutes      26
# 4    6a35ef7495303f29e7f85dbd54547fb1  4087936  starting_lineup      13
# ..                                ...      ...              ...     ...
# 214  ec3d266094f99ca0a8847de827e37105  4194152  starting_lineup       7
# 215  667840cda9bdf3b0344b8e99b306cf38  4194152  starting_lineup      23
# 216  1c5d2f60ee777760f8a757aa10c42bb1  4194154  starting_lineup      13
# 217  99032084fd00ffbfee52c541a9f960ab  4204000      substitutes      14
# 218  5c9eaf6ebb621d43a0d6fd6a9e607ef9  4220942      substitutes      13
#
#      player_id          player_name  team_captain          position
# ...

# %%
game_event_file=pd.read_excel(r"C:\Users\91994\Desktop\Sprint data\Capstone project data\game_events.xlsx")
game_event_file
# Out:
#                          game_event_id       date  game_id  minute  \
# 0     c6a3c088ed8a38d4ce074dd73b20d3da 2012-08-19  2221641      62
# 1     02d605a5c2dc4f9a6721daa583fa5405 2012-08-26  2222536      54
# 2     b56c2e2e087cddb3cfe9e3d340975df9 2012-11-18  2222707      79
# 3     4a15d1fff4f476f48bb60092c61641d5 2012-11-23  2222721      72
# 4     daa97877f7edf2fda885b411d7197921 2013-05-17  2222782      63
# ...                                ...        ...      ...     ...
# 1844  4acebccbc824e45d51045d8c5e164341 2023-10-31  4194147       3
# 1845  159ad5633cf9d7c3a97b593efb6c3269 2023-10-31  4194147       9
# 1846  daa31f19aab26eec375884aef73c73b3 2023-10-31  4194147      65
# 1847  869a13060604e769290dafe0b1f14483 2023-11-01  4194152      70
# 1848  6b7ed06f13c1f67f0d7359c310f20ba0 2023-10-31  4194154      76
#
#                type  player_id  \
# 0     Substitutions       1335
# 1             Cards       1321
# 2     Substitutions     104203
# ...

# %%
app_file=pd.read_excel(r"C:\Users\91994\Desktop\Sprint data\Capstone project data\appearances.xlsx")
app_file
# Out:
#        appearance_id  game_id  player_id       date          player_name  \
# 0     2224728_119169  2224728     119169 2012-07-13      Aron Johannsson
# 1     2224732_161244  2224732     161244 2012-07-14        Conor O'Brien
# 2      2224729_39467  2224729      39467 2012-07-15     Clarence Goodson
# 3     2232104_119169  2232104     119169 2012-07-19      Aron Johannsson
# 4      2219794_39475  2219794      39475 2012-07-22       Sacha Kljestan
# ...              ...      ...        ...        ...                  ...
# 3563  3415291_537467  3415291     537467 2020-09-26        Joseph Efford
# 3564  3415296_367423  3415296     367423 2020-09-26         Chris Durkin
# 3565  3431983_478940  3431983     478940 2020-09-26        Reggie Cannon
# 3566  3450575_361104  3450575     361104 2020-09-26         Sergino Dest
# 3567  3412904_124732  3412904     124732 2020-09-27  John Anthony Brooks
#
#      competition_id  yellow_cards  red_cards  goals  assists  minutes_played
# ...

# %%
df=app_file.merge(game_event_file,on=['game_id','player_id'],how='outer')
df1=df.merge(game_lineup_file,on=['game_id','player_id'],how='outer')
df2=df1.merge(games_file,on='game_id',how='outer')
df3=pd.merge(df2,players_file,on='player_id',how='outer')
df3
# Out:
#      appearance_id    game_id  player_id     date_x   player_name_x  \
# 0     2222536_1321  2222536.0       1321 2012-08-26  Jermaine Jones
# 1     2231391_1321  2231391.0       1321 2012-09-01  Jermaine Jones
# 2     2231391_1321  2231391.0       1321 2012-09-01  Jermaine Jones
# 3     2231397_1321  2231397.0       1321 2012-09-28  Jermaine Jones
# 4     2231397_1321  2231397.0       1321 2012-09-28  Jermaine Jones
# ...            ...        ...        ...        ...             ...
# 4649           NaN        NaN     795738        NaT             NaN
# 4650           NaN        NaN     796429        NaT             NaN
# 4651           NaN        NaN     860812        NaT             NaN
# 4652           NaN        NaN     971613        NaT             NaN
# 4653           NaN        NaN    1163778        NaT             NaN
#
#      competition_id_x  yellow_cards  red_cards  goals  assists  ...  \
# 0                  L1           1.0        0.0    0.0      1.0  ...
# ...

# %%
df3.isnull().sum()
# Out:
# appearance_id                   932
# game_id                          60
# player_id                         0
# date_x                          932
# player_name_x                   932
# competition_id_x                932
# yellow_cards                    932
# red_cards                       932
# goals                           932
# assists                         932
# minutes_played                  932
# game_event_id                  2805
# date_y                         2805
# minute                         2805
# type_x                         2805
# description                    3738
# player_in_id                   3499
# player_assist_id               4514
# game_lineups_id                4419
# type_y                         4419
# number                         4419
# player_name_y                  4419
# team_captain                   4419
# position_x                     4419
# competition_id_y                928
# season                          928
# ...

# %%
df3.drop(columns=['home_club_formation', 'away_club_formation'],inplace=True)

# %%
df3.dtypes
# Out:
# appearance_id                          object
# game_id                               float64
# player_id                               int64
# date_x                         datetime64[ns]
# player_name_x                          object
# competition_id_x                       object
# yellow_cards                          float64
# red_cards                             float64
# goals                                 float64
# assists                               float64
# minutes_played                        float64
# game_event_id                          object
# date_y                         datetime64[ns]
# minute                                float64
# type_x                                 object
# description                            object
# player_in_id                          float64
# player_assist_id                      float64
# game_lineups_id                        object
# type_y                                 object
# ...

# %%
import pandas as pd
import numpy as np

# Assuming 'df' is your dataframe
# Numerical Columns
numerical_cols = df3.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_cols:
    if df3[col].isnull().sum() > 0:
        df3[col].fillna(df3[col].mean(), inplace=True)

# Categorical Columns
categorical_cols = df3.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    if df3[col].isnull().sum() > 0:
        df3[col].fillna(df3[col].mode()[0], inplace=True)

# Datetime Columns
datetime_cols = df3.select_dtypes(include=['datetime64[ns]']).columns
for col in datetime_cols:
    if df3[col].isnull().sum() > 0:
        # Replace with the median date
        df3[col].fillna(df3[col].median(), inplace=True)

# %%
df3.isnull().sum()
# Out:
# appearance_id                  0
# game_id                        0
# player_id                      0
# date_x                         0
# player_name_x                  0
# competition_id_x               0
# yellow_cards                   0
# red_cards                      0
# goals                          0
# assists                        0
# minutes_played                 0
# game_event_id                  0
# date_y                         0
# minute                         0
# type_x                         0
# description                    0
# player_in_id                   0
# player_assist_id               0
# game_lineups_id                0
# type_y                         0
# number                         0
# player_name_y                  0
# team_captain                   0
# position_x                     0
# competition_id_y               0
# season                         0
# round                          0
# date                           0
# ...

# %%
# Assuming df3 is your merged dataframe after the previous steps

# Loop through numerical columns to calculate IQR and remove outliers
for col in df3.select_dtypes(include=['number']).columns:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df3[col].quantile(0.25)
    Q3 = df3[col].quantile(0.75)
    
    # Calculate the IQR
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter out rows that are outside the bounds
    df3 = df3[(df3[col] >= lower_bound) & (df3[col] <= upper_bound)]

# Display the cleaned dataframe without outliers
print(df3)
# Out:
#        appearance_id    game_id  player_id     date_x     player_name_x  \
# 5       2231422_1321  2231422.0       1321 2012-09-15    Jermaine Jones
# 7       2231439_1321  2231439.0       1321 2012-11-27    Jermaine Jones
# 8       2231442_1321  2231442.0       1321 2012-12-01    Jermaine Jones
# 12      2231491_1321  2231491.0       1321 2012-10-27    Jermaine Jones
# 14      2231504_1321  2231504.0       1321 2012-10-20    Jermaine Jones
# ...              ...        ...        ...        ...               ...
# 4575  3210456_544931  3210456.0     544931 2020-06-07  Christian Cappis
# 4600  3203721_578539  3203721.0     578539 2020-06-20    Chris Richards
# 4624  3058674_605498  3058674.0     605498 2019-04-06    Sebastian Soto
# 4625  3058681_605498  3058681.0     605498 2019-04-13    Sebastian Soto
# 4626  3058688_605498  3058688.0     605498 2019-04-21    Sebastian Soto
#
#      competition_id_x  yellow_cards  red_cards  goals  assists  ...  \
# ...

# %%
df3.to_csv('Football_Data_Merged_Cleaned.csv', index=False)

print("File saved as 'football_data_merged_cleaned.csv'")
# Out:
# File saved as 'football_data_merged_cleaned.csv'

# %%
df3
# Out:
#        appearance_id    game_id  player_id     date_x     player_name_x  \
# 5       2231422_1321  2231422.0       1321 2012-09-15    Jermaine Jones
# 7       2231439_1321  2231439.0       1321 2012-11-27    Jermaine Jones
# 8       2231442_1321  2231442.0       1321 2012-12-01    Jermaine Jones
# 12      2231491_1321  2231491.0       1321 2012-10-27    Jermaine Jones
# 14      2231504_1321  2231504.0       1321 2012-10-20    Jermaine Jones
# ...              ...        ...        ...        ...               ...
# 4575  3210456_544931  3210456.0     544931 2020-06-07  Christian Cappis
# 4600  3203721_578539  3203721.0     578539 2020-06-20    Chris Richards
# 4624  3058674_605498  3058674.0     605498 2019-04-06    Sebastian Soto
# 4625  3058681_605498  3058681.0     605498 2019-04-13    Sebastian Soto
# 4626  3058688_605498  3058688.0     605498 2019-04-21    Sebastian Soto
#
#      competition_id_x  yellow_cards  red_cards  goals  assists  ...  \
# ...
